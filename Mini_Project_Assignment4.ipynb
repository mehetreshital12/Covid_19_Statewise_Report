# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('covid_vaccine_statewise.csv')

# %%
df.describe()
# Out:
#        Total Doses Administered      Sessions        Sites
# count              7.621000e+03  7.621000e+03   7621.000000  \
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered
# count             7.621000e+03              7.621000e+03  \
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
df['First Dose Administered'].value_counts()
# Out:
# First Dose Administered
# 1824.0        7
# 807.0         7
# 2780.0        6
# 7304.0        6
# 48312.0       4
#              ..
# 2706244.0     1
# 2657655.0     1
# 2596134.0     1
# 2544240.0     1
# 23257417.0    1
# Name: count, Length: 7367, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
x = df["First Dose Administered"]
  
plt.hist(x, bins = 10, color = "green")
plt.title("First Dose Administered")
plt.xlabel("First Dose Administered")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data=df,x='First Dose Administered',bins=25,color='green')
plt.show()

# %%
df['Second Dose Administered'].value_counts()
# Out:
# Second Dose Administered
# 0.0          1048
# 107.0           8
# 37259.0         6
# 674.0           6
# 35326.0         5
#              ...
# 612135.0        1
# 591232.0        1
# 575470.0        1
# 566625.0        1
# 9132961.0       1
# Name: count, Length: 6275, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data=df,x='Second Dose Administered',bins=25,color='green')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
x = df["Second Dose Administered"]
  
plt.hist(x, bins = 25, color = "green")
plt.title("Second Dose Administered")
plt.xlabel("Second Dose Administered")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Male(Individuals Vaccinated)'].value_counts()
# Out:
# Male(Individuals Vaccinated)
# 6008960.0      2
# 23757.0        1
# 68616643.0     1
# 64611787.0     1
# 65445771.0     1
#               ..
# 11974143.0     1
# 12747867.0     1
# 12832126.0     1
# 14090723.0     1
# 134941971.0    1
# Name: count, Length: 159, dtype: int64

# %%
df['Female(Individuals Vaccinated)'].value_counts()
# Out:
# Female(Individuals Vaccinated)
# 5131373.0      2
# 24517.0        1
# 62424602.0     1
# 59183960.0     1
# 59914751.0     1
#               ..
# 9795767.0      1
# 10409393.0     1
# 10483269.0     1
# 11524956.0     1
# 115668447.0    1
# Name: count, Length: 159, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
x = df["Female(Individuals Vaccinated)"]
  
plt.hist(x, bins = 25, color = "green")
plt.title("No Of Female Vaccinated ")
plt.xlabel("Female Vaccinated")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
x = df["Male(Individuals Vaccinated)"]
  
plt.hist(x, bins = 25, color = "green")
plt.title("No Of Male Vaccinated ")
plt.xlabel("Male Vaccinated")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites
# 0     16/01/2021        India                   48276.0    3455.0   2957.0  \
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered
# ...

# %%
first_dose=df.groupby('State')['First Dose Administered'].sum()

# %%
first_dose
# Out:
# State
# Andaman and Nicobar Islands                 1.642585e+07
# Andhra Pradesh                              1.232861e+09
# Arunachal Pradesh                           4.900498e+07
# Assam                                       5.856002e+08
# Bihar                                       1.470503e+09
# Chandigarh                                  4.470310e+07
# Chhattisgarh                                7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu    3.359506e+07
# Delhi                                       6.243395e+08
# Goa                                         7.599137e+07
# Gujarat                                     2.131646e+09
# Haryana                                     7.557984e+08
# Himachal Pradesh                            3.162940e+08
# India                                       2.826214e+10
# Jammu and Kashmir                           4.101018e+08
# Jharkhand                                   6.036737e+08
# ...

# %%
first_dose=df.groupby('State')['First Dose Administered'].sum().toframe('Total')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13128\1992179278.py in ?()
# ----> 1 first_dose=df.groupby('State')['First Dose Administered'].sum().toframe('Total')
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'toframe'

# %%
second_dose=df.groupby(by='State')['Second Dose Administered'].sum()

# %%
second_dose
# Out:
# State
# Andaman and Nicobar Islands                 4.118554e+06
# Andhra Pradesh                              3.588176e+08
# Arunachal Pradesh                           1.193232e+07
# Assam                                       1.307888e+08
# Bihar                                       2.707906e+08
# Chandigarh                                  1.159374e+07
# Chhattisgarh                                1.721204e+08
# Dadra and Nagar Haveli and Daman and Diu    4.594416e+06
# Delhi                                       1.882189e+08
# Goa                                         1.619817e+07
# Gujarat                                     6.004184e+08
# Haryana                                     1.586561e+08
# Himachal Pradesh                            7.383858e+07
# India                                       6.759621e+09
# Jammu and Kashmir                           8.595165e+07
# Jharkhand                                   1.221211e+08
# ...

# %%
df['Male(Individuals Vaccinated)'].value_counts()
# Out:
# Male(Individuals Vaccinated)
# 6008960.0      2
# 23757.0        1
# 68616643.0     1
# 64611787.0     1
# 65445771.0     1
#               ..
# 11974143.0     1
# 12747867.0     1
# 12832126.0     1
# 14090723.0     1
# 134941971.0    1
# Name: count, Length: 159, dtype: int64
